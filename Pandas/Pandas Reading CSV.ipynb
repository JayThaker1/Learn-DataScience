# %% [markdown]
# ## Reading CSV in Pandas

# %%
import pandas as pd

# %% [markdown]
# Reading a CSV Dataset

# %%
pd.read_csv('C:\\Users\\asus\\Downloads\\Movies\\AI India Playlist\\Data Collection Sample\\Student_Data.csv')
# Out:
#    Student ID Preferred Name First Name Middle Name  Last Name Secondary ID  \
# 0        1001           Luke       Luke      Porter     Baxley        Q1001
# 1        1002         Marnie     Marnie       Gayle    Lemmons        Q1002
# 2        1003           Anne       Anne       Faith      Scott        Q1003
# 3        1004           Lucy       Lucy       Belle  Blakeslee        Q1004
# 4        1005        Chelsea    Chelsea    Savannah   Vlassman        Q1005
# 5        1006          Kelly      Kelly     Marilyn     Hudson        Q1006
# 6        1007           Todd       Todd  Washington  Robertson        Q1007
# 7        1008           Kirk       Kirk      Jeremy   Mitchell        Q1008
# 8        1009        Suzanne    Suzanne    Kathleen       Dunn        Q1009
#
#   Date of Birth        E-mail Address       Phone 1  \
# 0    01-02-1998  lpb@myUniversity.com  780-883-7269
# 1    11-07-1998  mgl@myUniversity.com  826-443-7227
# ...

# %% [markdown]
# Reading a Series Data in CSV

# %%
pd.read_csv('C:\\Users\\asus\\Downloads\\Movies\\AI India Playlist\\Data Collection Sample\\Top Ten IT Companies in India.csv')
# Out:
#   Top Ten IT Companies in India
# 0                           TCS
# 1                       Infosys
# 2                 Tech Mahindra
# 3                         Wipro
# 4              HCL Technologies
# 5                  L&T Infotech
# 6                      Mindtree
# 7                       Mphasis
# 8     Oracle Financial Services
# 9                   Rotla India

# %% [markdown]
# Import os module to access directories

# %%
import os

# %% [markdown]
# To get the current working directory

# %%
print(os.getcwd())
# Out:
# c:\Users\asus\Documents\Python Coding Work\Learn DataScience\Pandas
